# %% [markdown]
# ## Import Packages

# %%
# Import basic packages
import numpy as np
import scipy as sp
import pandas as pd
from scipy import interpolate
import random, os, time
import h5py

from astropy.nddata import block_reduce

from models import make_model

# Colab in order to download files
#from google.colab import files

# =========================================
# =========================================
# scikit-learn for Machine Learn

# Preprocessing
from sklearn.preprocessing import StandardScaler #Standar scaler for standardization
from sklearn.manifold import TSNE # Dimensionality reduction technique
from sklearn.model_selection import GridSearchCV #Cross-Validation
from sklearn.utils import resample #Resampling
# Classifiers
from sklearn.svm import SVC #Support Vector Classifier
from sklearn.ensemble import RandomForestClassifier as RF #Random Forests
# Metrics
from sklearn.metrics import accuracy_score 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# =======================================
# =======================================
# Tensorflow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import regularizers
from tensorflow.keras import optimizers
# Keras Layers
from keras.layers import InputLayer
from keras.layers import Conv2D
from keras.layers import BatchNormalization
from keras.layers import Dropout
from keras.layers import MaxPool2D
from keras.layers import Flatten
from keras.layers import Dense

# ==============================================
# ==============================================
# Matplotlib, seaborn and plot pretty 
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
# %matplotlib inline
from matplotlib import rcParams
rcParams['font.family'] = 'serif'

# Adjust rc parameters to make plots pretty
def plot_pretty(dpi=200, fontsize=9):
    

    plt.rc("savefig", dpi=dpi)       # dpi resolution of saved image files
    plt.rc('text', usetex=False)      # use LaTeX to process labels
    plt.rc('font', size=fontsize)    # fontsize
    plt.rc('xtick', direction='in')  # make axes ticks point inward
    plt.rc('ytick', direction='in')
    plt.rc('xtick.major', pad=10) 
    plt.rc('xtick.minor', pad=5)
    plt.rc('ytick.major', pad=10) 
    plt.rc('ytick.minor', pad=5)
    plt.rc('lines', dotted_pattern = [0.5, 1.1]) # fix dotted lines

    return

plot_pretty()

# Pillow
from PIL import Image

#Magic that allows me to have memory :)
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)

#jupyter inline magic
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# Out:
# 2022-09-27 16:40:36.914440: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31016 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0004:04:00.0, compute capability: 7.0
# 2022-09-27 16:40:36.917065: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 31016 MB memory:  -> device: 1, name: Tesla V100-SXM2-32GB, pci bus id: 0004:05:00.0, compute capability: 7.0
# 2022-09-27 16:40:36.919470: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 31016 MB memory:  -> device: 2, name: Tesla V100-SXM2-32GB, pci bus id: 0035:03:00.0, compute capability: 7.0
# 2022-09-27 16:40:36.921856: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 31016 MB memory:  -> device: 3, name: Tesla V100-SXM2-32GB, pci bus id: 0035:04:00.0, compute capability: 7.0

# %%
data_dir = '/project/r/rbond/jorlo/datasets/ml-clusters/for-debug/'

cut = 1000

# %%
pos_im_act = []
pos_im_des = []
neg_im = []

for directory in os.listdir(data_dir):
    print(directory)
    if directory[:3] == 'act' and (int(directory[4:8]) < cut):
        h5f = h5py.File(data_dir+directory)
        pos_im_act.append(h5f['act'][:])
    elif directory[:3] == 'des' and (int(directory[4:8]) < cut):
        h5f = h5py.File(data_dir+directory)
        pos_im_des.append(h5f['des'][:])
    elif directory[:6]=='random' and (int(directory[7:11]) < cut):
        h5f = h5py.File(data_dir+directory)
        neg_im.append(h5f['random'][:])


pos_im_act = np.vstack(pos_im_act)
pos_im_des = np.vstack(pos_im_des)
neg_im = np.vstack(neg_im)


pos_im = np.concatenate((pos_im_act, pos_im_des))


flags = []
for i in range(pos_im.shape[0]):
        if np.any(np.isnan(pos_im[i,...])):
                flags.append(i)

pos_im = np.delete(pos_im, flags, axis = 0)

flags = []
for i in range(neg_im.shape[0]):
        if np.any(np.isnan(neg_im[i,...])):
                flags.append(i)

neg_im = np.delete(neg_im, flags, axis = 0)


neg_im = neg_im[:len(pos_im)]
pos_im = pos_im[:len(neg_im)]

print(len(pos_im), len(neg_im))

save_neg_im = neg_im
save_pos_im = pos_im
# Out:
# random_2000_w_y.h5
# des_5000_w_y.h5
# des_2000_w_y.h5
# random_0000_w_y.h5
# des_0000_w_y.h5
# des_1000_w_y.h5
# random_6000_w_y.h5
# random_7000_w_y.h5
# random_5000_w_y.h5
# des_6000_w_y.h5
# act_1000_w_y.h5
# random_4000_w_y.h5
# random_3000_w_y.h5
# act_3000_w_y.h5
# des_4000_w_y.h5
# random_1000_w_y.h5
# act_0000_w_y.h5
# des_3000_w_y.h5
# 922 922

# %%
reduce = 4

if reduce:
    neg_im_2 = []
    pos_im_2 = []

    for i in range(len(neg_im)):
        neg_im_2.append(block_reduce(save_neg_im[i], [reduce,reduce,1], func = np.mean))
        pos_im_2.append(block_reduce(save_pos_im[i], [reduce,reduce,1], func = np.mean))
        

    pos_im = np.array(pos_im_2)
    neg_im = np.array(neg_im_2)

# %%
pos_im, neg_im = pos_im[...,:3], neg_im[...,:3]

input_shape = pos_im.shape[1:]

tot = min(pos_im.shape[0], neg_im.shape[0])
train_size = int(0.7 * tot)
val_size = int(0.15 * tot)
test_size = int(0.15 * tot)

train_pos = pos_im[:train_size]
val_pos = pos_im[train_size:train_size + val_size]
test_pos = pos_im[train_size + val_size:]

train_neg = neg_im[:train_size]
val_neg = neg_im[train_size:train_size + val_size]
test_neg = neg_im[train_size + val_size:]

input_shape = train_pos.shape[1:]

train_images = np.concatenate((train_pos,train_neg))
val_images = np.concatenate((val_pos,val_neg))
test_images = np.concatenate((test_pos,test_neg))

train_labels = np.array(train_pos.shape[0]*[1] + train_neg.shape[0]*[0])
val_labels = np.array(val_pos.shape[0]*[1] + val_neg.shape[0]*[0])
test_labels = np.array(test_pos.shape[0]*[1] + test_neg.shape[0]*[0])

batch_size = 500
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
val_dataset = tf.data.Dataset.from_tensor_slices((val_images, val_labels))
test_dataset = tf.data.Dataset.from_tensor_slices((test_images, test_labels))

train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)
val_dataset = val_dataset.shuffle(buffer_size=1024).batch(batch_size)
test_dataset = test_dataset.shuffle(buffer_size=1024).batch(batch_size)

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
val_dataset = val_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

print('Input shape: ', input_shape)
# Out:
# 2022-09-27 16:41:05.637114: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31016 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0004:04:00.0, compute capability: 7.0
# 2022-09-27 16:41:05.639379: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 31016 MB memory:  -> device: 1, name: Tesla V100-SXM2-32GB, pci bus id: 0004:05:00.0, compute capability: 7.0
# 2022-09-27 16:41:05.641609: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 31016 MB memory:  -> device: 2, name: Tesla V100-SXM2-32GB, pci bus id: 0035:03:00.0, compute capability: 7.0
# 2022-09-27 16:41:05.643829: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 31016 MB memory:  -> device: 3, name: Tesla V100-SXM2-32GB, pci bus id: 0035:04:00.0, compute capability: 7.0

# %%
model = make_model('DeepShadows', input_shape = input_shape, kernel_regularizer=regularizers.l2(0.001))


data_augmentation = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=360, width_shift_range=4,
    height_shift_range=4,zoom_range=0.3)
checkpoint_path = "/scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt"

name = 'DeepShadows'

checkpoint_dir = os.path.dirname(checkpoint_path)

def get_callbacks(name):
    return [tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1),
      tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=100),
      tf.keras.callbacks.TensorBoard(checkpoint_dir+name),
    ]        
toc = time.time()
history = model.fit(data_augmentation.flow(train_images, train_labels), epochs=int(100), 
                    validation_data=val_dataset, callbacks=get_callbacks(name))
tic = time.time()

print('Distributed time: ', tic-toc)
test_loss, test_acc = model.evaluate(test_dataset, verbose=2)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# Number of devices: 4
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 99, 99, 16)        448
#
#  batch_normalization_3 (Batc  (None, 99, 99, 16)       64
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 49, 49, 16)       0
#  2D)
#
#  dropout_3 (Dropout)         (None, 49, 49, 16)        0
#
#  conv2d_4 (Conv2D)           (None, 49, 49, 32)        4640
#
#  batch_normalization_4 (Batc  (None, 49, 49, 32)       128
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 24, 24, 32)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 24, 24, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 24, 24, 64)        18496
#
#  batch_normalization_5 (Batc  (None, 24, 24, 64)       256
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 12, 12, 64)        0
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dense_2 (Dense)             (None, 1024)              9438208
#
#  dense_3 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 9,463,265
# Trainable params: 9,463,041
# Non-trainable params: 224
# _________________________________________________________________
# Epoch 1/100
# 41/41 [==============================] - ETA: 0s - loss: 195.7065 - accuracy: 0.5295
# Epoch 1: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 4s 78ms/step - loss: 195.7065 - accuracy: 0.5295 - val_loss: 163.5932 - val_accuracy: 0.5217
# Epoch 2/100
# 41/41 [==============================] - ETA: 0s - loss: 142.7084 - accuracy: 0.5364
# Epoch 2: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 74ms/step - loss: 142.7084 - accuracy: 0.5364 - val_loss: 123.0370 - val_accuracy: 0.4710
# Epoch 3/100
# 41/41 [==============================] - ETA: 0s - loss: 109.4587 - accuracy: 0.5256
# Epoch 3: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 79ms/step - loss: 109.4587 - accuracy: 0.5256 - val_loss: 95.7490 - val_accuracy: 0.5290
# Epoch 4/100
# 41/41 [==============================] - ETA: 0s - loss: 86.2396 - accuracy: 0.5411
# Epoch 4: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 86.2396 - accuracy: 0.5411 - val_loss: 76.4939 - val_accuracy: 0.4710
# Epoch 5/100
# 41/41 [==============================] - ETA: 0s - loss: 69.4128 - accuracy: 0.5233
# Epoch 5: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 72ms/step - loss: 69.4128 - accuracy: 0.5233 - val_loss: 62.2299 - val_accuracy: 0.4891
# Epoch 6/100
# 41/41 [==============================] - ETA: 0s - loss: 56.8715 - accuracy: 0.5395
# Epoch 6: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s
saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 1.3226 - accuracy: 0.6884 - val_loss: 1.2669 - val_accuracy: 0.7210
# Epoch 35/100
# 41/41 [==============================] - ETA: 0s - loss: 1.2853 - accuracy: 0.6884
# Epoch 35: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 72ms/step - loss: 1.2853 - accuracy: 0.6884 - val_loss: 1.1747 - val_accuracy: 0.7572
# Epoch 36/100
# 41/41 [==============================] - ETA: 0s - loss: 1.2051 - accuracy: 0.7147
# Epoch 36: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 1.2051 - accuracy: 0.7147 - val_loss: 1.1330 - val_accuracy: 0.7174
# Epoch 37/100
# 41/41 [==============================] - ETA: 0s - loss: 1.1609 - accuracy: 0.7109
# Epoch 37: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 74ms/step - loss: 1.1609 - accuracy: 0.7109 - val_loss: 1.0954 - val_accuracy: 0.7319
# Epoch 38/100
# 41/41 [==============================] - ETA: 0s - loss: 1.1153 - accuracy: 0.7225
# Epoch 38: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 72ms/step - loss: 1.1153 - accuracy: 0.7225 - val_loss: 1.0380 - val_accuracy: 0.7536
# Epoch 39/100
# 41/41 [==============================] - ETA: 0s - loss: 1.0983 - accuracy: 0.7070
# Epoch 39: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 76ms/step - loss: 1.0983 - accuracy: 0.7070 - val_loss: 1.0080 - val_accuracy: 0.7790
# Epoch 40/100
# 41/41 [==============================] - ETA: 0s - loss: 1.0372 - accuracy: 0.7295
# Epoch 40: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 1.0372 - accuracy: 0.7295 - val_loss: 0.9625 - val_accuracy: 0.8116
# Epoch 41/100
# 41/41 [==============================] - ETA: 0s - loss: 0.9915 - accuracy: 0.7473
# Epoch 41: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 74ms/step - loss: 0.9915 - accuracy: 0.7473 - val_loss: 0.9358 - val_accuracy: 0.8297
# Epoch 42/100
# 41/41 [==============================] - ETA: 0s - loss: 0.9653 - accuracy: 0.7434
# Epoch 42: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 74ms/step - loss: 0.9653 - accuracy: 0.7434 - val_loss: 0.9589 - val_accuracy: 0.7355
# Epoch 43/100
# 41/41 [==============================] - ETA: 0s - loss: 0.9318 - accuracy: 0.7566
# Epoch 43: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.9318 - accuracy: 0.7566 - val_loss: 0.8929 - val_accuracy: 0.8080
# Epoch 44/100
# 41/41 [==============================] - ETA: 0s - loss: 0.9032 - accuracy: 0.7612
# Epoch 44: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.9032 - accuracy: 0.7612 - val_loss: 0.9443 - val_accuracy: 0.7246
# Epoch 45/100
# 41/41 [==============================] - ETA: 0s - loss: 0.8714 - accuracy: 0.7760
# Epoch 45: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 74ms/step - loss: 0.8714 - accuracy: 0.7760 - val_loss: 0.8083 - val_accuracy: 0.8478
# Epoch 46/100
# 41/41 [==============================] - ETA: 0s - loss: 0.8431 - accuracy: 0.7907
# Epoch 46: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 74ms/step - loss: 0.8431 - accuracy: 0.7907 - val_loss: 0.7947 - val_accuracy: 0.8406
# Epoch 47/100
# 41/41 [==============================] - ETA: 0s - loss: 0.8099 - accuracy: 0.7977
# Epoch 47: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.8099 - accuracy: 0.7977 - val_loss: 0.7375 - val_accuracy: 0.8514
# Epoch 48/100
# 41/41 [==============================] - ETA: 0s - loss: 0.8027 - accuracy: 0.8047
# Epoch 48: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 74ms/step - loss: 0.8027 - accuracy: 0.8047 - val_loss: 0.7625 - val_accuracy: 0.8478
# Epoch 49/100
# 41/41 [==============================] - ETA: 0s - loss: 0.7768 - accuracy: 0.8008
# Epoch 49: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 74ms/step - loss: 0.7768 - accuracy: 0.8008 - val_loss: 0.7679 - val_accuracy: 0.8370
# Epoch 50/100
# 41/41 [==============================] - ETA: 0s - loss: 0.7617 - accuracy: 0.8023
# Epoch 50: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 74ms/step - loss: 0.7617 - accuracy: 0.8023 - val_loss: 0.6690 - val_accuracy: 0.9203
# Epoch 51/100
# 41/41 [==============================] - ETA: 0s - loss: 0.7408 - accuracy: 0.8109
# Epoch 51: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 74ms/step - loss: 0.7408 - accuracy: 0.8109 - val_loss: 0.7006 - val_accuracy: 0.8768
# Epoch 52/100
# 41/41 [==============================] - ETA: 0s - loss: 0.7275 - accuracy: 0.8171
# Epoch 52: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 74ms/step - loss: 0.7275 - accuracy: 0.8171 - val_loss: 0.6299 - val_accuracy: 0.9203
# Epoch 53/100
# 41/41 [==============================] - ETA: 0s - loss: 0.7400 - accuracy: 0.8132
# Epoch 53: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.7400 - accuracy: 0.8132 - val_loss: 0.6884 - val_accuracy: 0.8442
# Epoch 54/100
# 41/41 [==============================] - ETA: 0s - loss: 0.6983 - accuracy: 0.8093
# Epoch 54: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 76ms/step - loss: 0.6983 - accuracy: 0.8093 - val_loss: 0.7264 - val_accuracy: 0.7862
# Epoch 55/100
# 41/41 [==============================] - ETA: 0s - loss: 0.6756 - accuracy: 0.8178
# Epoch 55: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 74ms/step - loss: 0.6756 - accuracy: 0.8178 - val_loss: 0.7547 - val_accuracy: 0.7899
# Epoch 56/100
# 41/41 [==============================] - ETA: 0s - loss: 0.6867 - accuracy: 0.8209
# Epoch 56: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 78ms/step - loss: 0.6867 - accuracy: 0.8209 - val_loss: 0.5727 - val_accuracy: 0.9094
# Epoch 57/100
# 41/41 [==============================] - ETA: 0s - loss: 0.6643 - accuracy: 0.8225
# Epoch 57: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 74ms/step - loss: 0.6643 - accuracy: 0.8225 - val_loss: 0.6325 - val_accuracy: 0.8804
# Epoch 58/100
# 41/41 [==============================] - ETA: 0s - loss: 0.6539 - accuracy: 0.8271
# Epoch 58: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.6539 - accuracy: 0.8271 - val_loss: 0.5730 - val_accuracy: 0.8913
# Epoch 59/100
# 41/41 [==============================] - ETA: 0s - loss: 0.6394 - accuracy: 0.8295
# Epoch 59: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 74ms/step - loss: 0.6394 - accuracy: 0.8295 - val_loss: 0.5622 - val_accuracy: 0.9203
# Epoch 60/100
# 41/41 [==============================] - ETA: 0s - loss: 0.6298 - accuracy: 0.8271
# Epoch 60: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 74ms/step - loss: 0.6298 - accuracy: 0.8271 - val_loss: 0.6660 - val_accuracy: 0.8333
# Epoch 61/100
# 41/41 [==============================] - ETA: 0s - loss: 0.6097 - accuracy: 0.8357
# Epoch 61: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.6097 - accuracy: 0.8357 - val_loss: 0.6612 - val_accuracy: 0.8551
# Epoch 62/100
# 41/41 [==============================] - ETA: 0s - loss: 0.5976 - accuracy: 0.8457
# Epoch 62: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.5976 - accuracy: 0.8457 - val_loss: 0.5865 - val_accuracy: 0.8659
# Epoch 63/100
# 41/41 [==============================] - ETA: 0s - loss: 0.5949 - accuracy: 0.8481
# Epoch 63: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.5949 - accuracy: 0.8481 - val_loss: 0.6619 - val_accuracy: 0.8514
# Epoch 64/100
# 41/41 [==============================] - ETA: 0s - loss: 0.6097 - accuracy: 0.8271
# Epoch 64: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.6097 - accuracy: 0.8271 - val_loss: 0.6140 - val_accuracy: 0.8514
# Epoch 65/100
# 41/41 [==============================] - ETA: 0s - loss: 0.5958 - accuracy: 0.8302
# Epoch 65: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.5958 - accuracy: 0.8302 - val_loss: 0.5130 - val_accuracy: 0.9420
# Epoch 66/100
# 41/41 [==============================] - ETA: 0s - loss: 0.5930 - accuracy: 0.8380
# Epoch 66: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.
100
# 41/41 [==============================] - ETA: 0s - loss: 0.5376 - accuracy: 0.8535
# Epoch 85: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.5376 - accuracy: 0.8535 - val_loss: 0.5366 - val_accuracy: 0.8949
# Epoch 86/100
# 41/41 [==============================] - ETA: 0s - loss: 0.5096 - accuracy: 0.8605
# Epoch 86: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.5096 - accuracy: 0.8605 - val_loss: 0.7016 - val_accuracy: 0.7500
# Epoch 87/100
# 41/41 [==============================] - ETA: 0s - loss: 0.5143 - accuracy: 0.8527
# Epoch 87: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.5143 - accuracy: 0.8527 - val_loss: 0.5544 - val_accuracy: 0.8551
# Epoch 88/100
# 41/41 [==============================] - ETA: 0s - loss: 0.5235 - accuracy: 0.8419
# Epoch 88: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.5235 - accuracy: 0.8419 - val_loss: 0.4801 - val_accuracy: 0.8986
# Epoch 89/100
# 41/41 [==============================] - ETA: 0s - loss: 0.5135 - accuracy: 0.8527
# Epoch 89: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.5135 - accuracy: 0.8527 - val_loss: 0.4487 - val_accuracy: 0.9058
# Epoch 90/100
# 41/41 [==============================] - ETA: 0s - loss: 0.5143 - accuracy: 0.8488
# Epoch 90: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.5143 - accuracy: 0.8488 - val_loss: 0.4391 - val_accuracy: 0.9239
# Epoch 91/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4871 - accuracy: 0.8581
# Epoch 91: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.4871 - accuracy: 0.8581 - val_loss: 0.5140 - val_accuracy: 0.8877
# Epoch 92/100
# 41/41 [==============================] - ETA: 0s - loss: 0.5145 - accuracy: 0.8457
# Epoch 92: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.5145 - accuracy: 0.8457 - val_loss: 0.6094 - val_accuracy: 0.7790
# Epoch 93/100
# 41/41 [==============================] - ETA: 0s - loss: 0.5082 - accuracy: 0.8465
# Epoch 93: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.5082 - accuracy: 0.8465 - val_loss: 0.5882 - val_accuracy: 0.8623
# Epoch 94/100
# 41/41 [==============================] - ETA: 0s - loss: 0.5007 - accuracy: 0.8496
# Epoch 94: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.5007 - accuracy: 0.8496 - val_loss: 0.5784 - val_accuracy: 0.8297
# Epoch 95/100
# 41/41 [==============================] - ETA: 0s - loss: 0.5151 - accuracy: 0.8426
# Epoch 95: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 72ms/step - loss: 0.5151 - accuracy: 0.8426 - val_loss: 0.5772 - val_accuracy: 0.8080
# Epoch 96/100
# 41/41 [==============================] - ETA: 0s - loss: 0.5036 - accuracy: 0.8519
# Epoch 96: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.5036 - accuracy: 0.8519 - val_loss: 0.5764 - val_accuracy: 0.8297
# Epoch 97/100
# 41/41 [==============================] - ETA: 0s - loss: 0.5020 - accuracy: 0.8388
# Epoch 97: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 73ms/step - loss: 0.5020 - accuracy: 0.8388 - val_loss: 0.4613 - val_accuracy: 0.8913
# Epoch 98/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4980 - accuracy: 0.8535
# Epoch 98: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 74ms/step - loss: 0.4980 - accuracy: 0.8535 - val_loss: 0.4380 - val_accuracy: 0.9022
# Epoch 99/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4908 - accuracy: 0.8558
# Epoch 99: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 72ms/step - loss: 0.4908 - accuracy: 0.8558 - val_loss: 0.4488 - val_accuracy: 0.9058
# Epoch 100/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4944 - accuracy: 0.8527
# Epoch 100: saving model to /scratch/r/rbond/jorlo/ml-clusters/models/DeepShadows.ckpt
# 41/41 [==============================] - 3s 72ms/step - loss: 0.4944 - accuracy: 0.8527 - val_loss: 0.6759 - val_accuracy: 0.7572
# Distributed time:  308.94493985176086
# 1/1 - 0s - loss: 0.6348 - accuracy: 0.7374 - 76ms/epoch - 76ms/step

# %%
test_loss, test_acc = model.evaluate(test_dataset, verbose=2)

print('\nTest accuracy: ', test_acc)
# Out:
# 1/1 - 0s - loss: 0.6348 - accuracy: 0.7374 - 78ms/epoch - 78ms/step
#
# Test accuracy:  0.7374100685119629
